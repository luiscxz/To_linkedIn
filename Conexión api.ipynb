# %% [markdown]
# **Tabla de contenido**
#
# - [Librerías](#Lib)

# %% [markdown]
# **Extracción de datos desde API Spotify**

# %% [markdown]
# # Lib

# %%
import pandas as pd
import polars as pl
import os
import json
import requests
from io import StringIO
import re

# %% [markdown]
# **Definamos la ruta de trabajo y la ruta donde están las credenciales**
#
# Este código hace lo siguiente:
#
# - **Busca las credenciales de Spotify**: Primero encuentra la carpeta actual donde está el programa (getcwd). Luego busca un archivo llamado "credentials_spotify.json" dentro de una subcarpeta llamada "secretos".
#
# - **Lee las credenciales**: Abre ese archivo y extrae dos datos importantes: el "Client ID" y el "Client secret" (como un usuario y contraseña para acceder a Spotify).
#
# - **Prepara los datos para pedir acceso**: Junta esas credenciales en un paquete de datos que indica que quiere acceder con credenciales de cliente.
# - **Pide un token de acceso a Spotify**: Envía esos datos al servidor de Spotify (a la dirección "token_url"). Spotify verifica si las credenciales son correctas.
#
# **Obtiene la respuesta**: Si todo está bien (código 200), recibe un "token" (como un pase temporal) que permitirá hacer peticiones a la API de Spotify. Si hay error, muestra qué salió mal.
#
# **En resumen**: el código obtiene un permiso temporal (token) de Spotify usando credenciales guardadas en un archivo secreto.

# %%
path = os.getcwd()
path_credenciales =os.path.join(path,'secretos','credentials_spotify.json')

# lee las credenciles
with open(path_credenciales) as f:
    credenciales = json.load(f)
    client_id = credenciales['Client ID']
    client_secret= credenciales['Client secret']

# guarda credenciales en variable data
data = {
    'grant_type':'client_credentials',
    'client_id':client_id,
    'client_secret':client_secret
}

# crea tokenurl
token_url = 'https://accounts.spotify.com/api/token'
response = requests.post(token_url,data=data)

if response.status_code==200:
    token = response.json()['access_token']
    print('token válido')
else:
    print('Error en la obtención del token')
    print(response.text)
# Out:
# token válido

# %% [markdown]
# **Estracción de datos desde un spotifi charts**
# https://open.spotify.com/track/7so0lgd0zP2Sbgs2d7a1SZ
#
# Este código hace una solicitud a la API de Spotify para obtener las características de audio (audio features) de una canción específica, identificada por su id_track

# %%
id_track = '7so0lgd0zP2Sbgs2d7a1SZ'
url = f'https://api.spotify.com/v1/audio-features/{id_track}'
headers = {
    'Authorization': f'Bearer {token}'
}
response = requests.get(url, headers=headers) 
print(response.json())
# Out:
# {'error': {'status': 403}}

# %% [markdown]
# **Consumo de API creada en mockaroo**
#
# Mockaroo es una herramienta en línea que permite generar datos falsos (mock data) de forma personalizada y realista para pruebas, desarrollo o demostraciones. Es muy útil cuando necesitas poblar bases de datos, probar APIs o entrenar modelos de machine learning sin usar datos reales o sensibles.

# %%
headers ={
    'X-API-Key':'2d672d60'
}
response = requests.get('https://my.api.mockaroo.com/a_pi.json',headers=headers)
response.json()
# Out:
# [{'Fecha': '6/21/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 5859,
#   'Impresiones': 52117,
#   'Views': 151573,
#   'Costo': 620},
#  {'Fecha': '8/26/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 1984,
#   'Impresiones': 15857,
#   'Views': 963171,
#   'Costo': 626},
#  {'Fecha': '8/28/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 8467,
#   'Impresiones': 65543,
#   'Views': 230241,
#   'Costo': 616},
#  {'Fecha': '9/22/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 5355,
#   'Impresiones': 23645,
#   'Views': 229958,
#   'Costo': 464},
#  {'Fecha': '3/19/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 5550,
#   'Impresiones': 69030,
#   'Views': 527332,
#   'Costo': 855},
#  {'Fecha': '12/18/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 8082,
#   'Impresiones': 75931,
#   'Views': 139991,
#   'Costo': 944},
#  {'Fecha': '11/23/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 1514,
#   'Impresiones': 65139,
#   'Views': 733535,
#   'Costo': 117},
#  {'Fecha': '9/29/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 3245,
#   'Impresiones': 36504,
#   'Views': 837531,
#   'Costo': 534},
#  {'Fecha': '7/19/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 3847,
#   'Impresiones': 85454,
#   'Views': 182180,
#   'Costo': 826},
#  {'Fecha': '8/3/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 5931,
#   'Impresiones': 93077,
#   'Views': 929858,
#   'Costo': 694},
#  {'Fecha': '10/7/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 4736,
#   'Impresiones': 83285,
#   'Views': 900377,
#   'Costo': 383},
#  {'Fecha': '9/15/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 7138,
#   'Impresiones': 91418,
#   'Views': 402030,
#   'Costo': 297},
#  {'Fecha': '5/30/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 270,
#   'Impresiones': 89486,
#   'Views': 196941,
#   'Costo': 17},
#  {'Fecha': '7/19/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 2553,
#   'Impresiones': 70536,
#   'Views': 878318,
#   'Costo': 8},
#  {'Fecha': '11/20/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Asia',
#   'Clics': 6006,
#   'Impresiones': 66954,
#   'Views': 676941,
#   'Costo': 186},
#  {'Fecha': '7/7/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Europe',
#   'Clics': 8859,
#   'Impresiones': 79396,
#   'Views': 953462,
#   'Costo': 735},
#  {'Fecha': '4/17/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Australia',
#   'Clics': 1985,
#   'Impresiones': 23402,
#   'Views': 46252,
#   'Costo': 531},
#  {'Fecha': '5/11/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 8151,
#   'Impresiones': 80846,
#   'Views': 204424,
#   'Costo': 864},
#  {'Fecha': '3/2/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 3286,
#   'Impresiones': 27123,
#   'Views': 110672,
#   'Costo': 591},
#  {'Fecha': '1/28/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 8344,
#   'Impresiones': 42866,
#   'Views': 115029,
#   'Costo': 994},
#  {'Fecha': '1/9/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 2069,
#   'Impresiones': 82493,
#   'Views': 581786,
#   'Costo': 70},
#  {'Fecha': '6/24/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 9888,
#   'Impresiones': 68399,
#   'Views': 605768,
#   'Costo': 547},
#  {'Fecha': '6/18/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 1374,
#   'Impresiones': 68123,
#   'Views': 430715,
#   'Costo': 382},
#  {'Fecha': '1/30/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 435,
#   'Impresiones': 13228,
#   'Views': 777780,
#   'Costo': 176},
#  {'Fecha': '4/11/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 9563,
#   'Impresiones': 25793,
#   'Views': 470484,
#   'Costo': 831},
#  {'Fecha': '5/22/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 5428,
#   'Impresiones': 52710,
#   'Views': 724092,
#   'Costo': 44},
#  {'Fecha': '9/12/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 3853,
#   'Impresiones': 75062,
#   'Views': 676935,
#   'Costo': 845},
#  {'Fecha': '10/27/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 7925,
#   'Impresiones': 17513,
#   'Views': 211693,
#   'Costo': 224},
#  {'Fecha': '5/1/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'South America',
#   'Clics': 6411,
#   'Impresiones': 93750,
#   'Views': 784444,
#   'Costo': 631},
#  {'Fecha': '1/2/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Africa',
#   'Clics': 5554,
#   'Impresiones': 93352,
#   'Views': 768119,
#   'Costo': 420},
#  {'Fecha': '6/30/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 5278,
#   'Impresiones': 74248,
#   'Views': 383072,
#   'Costo': 567},
#  {'Fecha': '4/5/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 4293,
#   'Impresiones': 34201,
#   'Views': 596192,
#   'Costo': 599},
#  {'Fecha': '11/2/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 303,
#   'Impresiones': 48139,
#   'Views': 399977,
#   'Costo': 839},
#  {'Fecha': '11/10/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'South America',
#   'Clics': 5633,
#   'Impresiones': 35323,
#   'Views': 258774,
#   'Costo': 977},
#  {'Fecha': '7/2/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 1509,
#   'Impresiones': 37626,
#   'Views': 130884,
#   'Costo': 192},
#  {'Fecha': '1/8/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 2749,
#   'Impresiones': 95808,
#   'Views': 73251,
#   'Costo': 214},
#  {'Fecha': '11/29/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 4693,
#   'Impresiones': 54853,
#   'Views': 747816,
#   'Costo': 484},
#  {'Fecha': '4/29/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 7839,
#   'Impresiones': 89927,
#   'Views': 495970,
#   'Costo': 567},
#  {'Fecha': '11/10/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Asia',
#   'Clics': 6092,
#   'Impresiones': 20308,
#   'Views': 367613,
#   'Costo': 697},
#  {'Fecha': '4/13/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 2517,
#   'Impresiones': 70523,
#   'Views': 197484,
#   'Costo': 372},
#  {'Fecha': '11/26/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Australia',
#   'Clics': 4370,
#   'Impresiones': 99970,
#   'Views': 779075,
#   'Costo': 185},
#  {'Fecha': '11/11/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 8584,
#   'Impresiones': 62003,
#   'Views': 824750,
#   'Costo': 746},
#  {'Fecha': '8/30/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 24,
#   'Impresiones': 26661,
#   'Views': 131308,
#   'Costo': 188},
#  {'Fecha': '2/3/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 3158,
#   'Impresiones': 57743,
#   'Views': 546531,
#   'Costo': 681},
#  {'Fecha': '9/4/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 9116,
#   'Impresiones': 75705,
#   'Views': 739105,
#   'Costo': 220},
#  {'Fecha': '4/22/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 8221,
#   'Impresiones': 39846,
#   'Views': 687826,
#   'Costo': 673},
#  {'Fecha': '3/19/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 9996,
#   'Impresiones': 32078,
#   'Views': 786639,
#   'Costo': 302},
#  {'Fecha': '10/29/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 2445,
#   'Impresiones': 25575,
#   'Views': 732124,
#   'Costo': 871},
#  {'Fecha': '5/15/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 3898,
#   'Impresiones': 58159,
#   'Views': 482948,
#   'Costo': 880},
#  {'Fecha': '12/12/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 7383,
#   'Impresiones': 77929,
#   'Views': 624108,
#   'Costo': 843},
#  {'Fecha': '12/7/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 4371,
#   'Impresiones': 88169,
#   'Views': 614867,
#   'Costo': 405},
#  {'Fecha': '12/2/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 5930,
#   'Impresiones': 16521,
#   'Views': 409349,
#   'Costo': 91},
#  {'Fecha': '10/15/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Asia',
#   'Clics': 7285,
#   'Impresiones': 78774,
#   'Views': 317408,
#   'Costo': 361},
#  {'Fecha': '3/2/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 3763,
#   'Impresiones': 58555,
#   'Views': 325650,
#   'Costo': 446},
#  {'Fecha': '1/22/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 4658,
#   'Impresiones': 51519,
#   'Views': 882763,
#   'Costo': 79},
#  {'Fecha': '1/30/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 4853,
#   'Impresiones': 12828,
#   'Views': 179145,
#   'Costo': 44},
#  {'Fecha': '10/4/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 7349,
#   'Impresiones': 50851,
#   'Views': 937550,
#   'Costo': 879},
#  {'Fecha': '5/22/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 5813,
#   'Impresiones': 60000,
#   'Views': 634360,
#   'Costo': 513},
#  {'Fecha': '3/5/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 9252,
#   'Impresiones': 20570,
#   'Views': 645791,
#   'Costo': 92},
#  {'Fecha': '9/28/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 1812,
#   'Impresiones': 9232,
#   'Views': 930628,
#   'Costo': 77},
#  {'Fecha': '2/27/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'South America',
#   'Clics': 7422,
#   'Impresiones': 21438,
#   'Views': 505538,
#   'Costo': 253},
#  {'Fecha': '12/8/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 6116,
#   'Impresiones': 72166,
#   'Views': 974339,
#   'Costo': 670},
#  {'Fecha': '3/24/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 1213,
#   'Impresiones': 33566,
#   'Views': 100116,
#   'Costo': 65},
#  {'Fecha': '7/3/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 7293,
#   'Impresiones': 8956,
#   'Views': 73119,
#   'Costo': 68},
#  {'Fecha': '1/3/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 9840,
#   'Impresiones': 58732,
#   'Views': 230232,
#   'Costo': 684},
#  {'Fecha': '6/22/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 8898,
#   'Impresiones': 56223,
#   'Views': 22336,
#   'Costo': 74},
#  {'Fecha': '12/16/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 318,
#   'Impresiones': 80080,
#   'Views': 857307,
#   'Costo': 508},
#  {'Fecha': '7/5/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 7171,
#   'Impresiones': 85333,
#   'Views': 627291,
#   'Costo': 260},
#  {'Fecha': '12/5/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 8767,
#   'Impresiones': 75746,
#   'Views': 284982,
#   'Costo': 914},
#  {'Fecha': '2/8/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 4766,
#   'Impresiones': 39148,
#   'Views': 60633,
#   'Costo': 218},
#  {'Fecha': '11/12/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 7054,
#   'Impresiones': 26305,
#   'Views': 425122,
#   'Costo': 983},
#  {'Fecha': '9/12/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 9821,
#   'Impresiones': 34501,
#   'Views': 504754,
#   'Costo': 795},
#  {'Fecha': '2/13/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 8951,
#   'Impresiones': 9853,
#   'Views': 724882,
#   'Costo': 395},
#  {'Fecha': '8/9/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 9986,
#   'Impresiones': 44460,
#   'Views': 630664,
#   'Costo': 718},
#  {'Fecha': '9/25/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 6661,
#   'Impresiones': 44236,
#   'Views': 563193,
#   'Costo': 535},
#  {'Fecha': '5/5/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 7568,
#   'Impresiones': 60177,
#   'Views': 525476,
#   'Costo': 322},
#  {'Fecha': '7/15/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 2899,
#   'Impresiones': 70689,
#   'Views': 89268,
#   'Costo': 170},
#  {'Fecha': '1/29/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 2926,
#   'Impresiones': 89523,
#   'Views': 836627,
#   'Costo': 481},
#  {'Fecha': '11/25/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 314,
#   'Impresiones': 75332,
#   'Views': 345756,
#   'Costo': 560},
#  {'Fecha': '11/30/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Asia',
#   'Clics': 6216,
#   'Impresiones': 920,
#   'Views': 372670,
#   'Costo': 843},
#  {'Fecha': '3/11/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 7597,
#   'Impresiones': 9528,
#   'Views': 630092,
#   'Costo': 971},
#  {'Fecha': '11/5/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 872,
#   'Impresiones': 10781,
#   'Views': 675059,
#   'Costo': 758},
#  {'Fecha': '6/29/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Africa',
#   'Clics': 1351,
#   'Impresiones': 87911,
#   'Views': 388210,
#   'Costo': 848},
#  {'Fecha': '1/13/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 2089,
#   'Impresiones': 20163,
#   'Views': 65718,
#   'Costo': 38},
#  {'Fecha': '4/7/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 5732,
#   'Impresiones': 69433,
#   'Views': 654880,
#   'Costo': 604},
#  {'Fecha': '3/8/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Asia',
#   'Clics': 5129,
#   'Impresiones': 45855,
#   'Views': 652052,
#   'Costo': 119},
#  {'Fecha': '9/14/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 2334,
#   'Impresiones': 92825,
#   'Views': 499739,
#   'Costo': 765},
#  {'Fecha': '2/6/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Africa',
#   'Clics': 1321,
#   'Impresiones': 30064,
#   'Views': 260915,
#   'Costo': 534},
#  {'Fecha': '7/9/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 734,
#   'Impresiones': 61949,
#   'Views': 491067,
#   'Costo': 652},
#  {'Fecha': '12/28/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Asia',
#   'Clics': 5151,
#   'Impresiones': 49474,
#   'Views': 768228,
#   'Costo': 676},
#  {'Fecha': '2/24/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 9706,
#   'Impresiones': 92236,
#   'Views': 142286,
#   'Costo': 815},
#  {'Fecha': '10/5/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'South America',
#   'Clics': 2066,
#   'Impresiones': 72786,
#   'Views': 831032,
#   'Costo': 309},
#  {'Fecha': '11/10/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 7943,
#   'Impresiones': 34064,
#   'Views': 272754,
#   'Costo': 743},
#  {'Fecha': '12/28/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 4127,
#   'Impresiones': 36685,
#   'Views': 472179,
#   'Costo': 337},
#  {'Fecha': '9/12/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 3728,
#   'Impresiones': 51966,
#   'Views': 81109,
#   'Costo': 356},
#  {'Fecha': '8/8/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 1396,
#   'Impresiones': 15877,
#   'Views': 476968,
#   'Costo': 253},
#  {'Fecha': '8/2/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 6197,
#   'Impresiones': 63115,
#   'Views': 317623,
#   'Costo': 663},
#  {'Fecha': '8/30/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 1899,
#   'Impresiones': 75049,
#   'Views': 208307,
#   'Costo': 384},
#  {'Fecha': '10/10/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Australia',
#   'Clics': 7239,
#   'Impresiones': 90275,
#   'Views': 767646,
#   'Costo': 122},
#  {'Fecha': '12/11/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 3036,
#   'Impresiones': 43582,
#   'Views': 63167,
#   'Costo': 153},
#  {'Fecha': '6/1/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 3604,
#   'Impresiones': 19811,
#   'Views': 207758,
#   'Costo': 555},
#  {'Fecha': '11/3/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 9400,
#   'Impresiones': 94238,
#   'Views': 827847,
#   'Costo': 440},
#  {'Fecha': '2/7/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 841,
#   'Impresiones': 81665,
#   'Views': 280670,
#   'Costo': 131},
#  {'Fecha': '12/16/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 6037,
#   'Impresiones': 85292,
#   'Views': 79987,
#   'Costo': 460},
#  {'Fecha': '8/5/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 8813,
#   'Impresiones': 7695,
#   'Views': 762030,
#   'Costo': 855},
#  {'Fecha': '9/15/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 8896,
#   'Impresiones': 41692,
#   'Views': 669233,
#   'Costo': 493},
#  {'Fecha': '3/19/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 1084,
#   'Impresiones': 28855,
#   'Views': 357298,
#   'Costo': 106},
#  {'Fecha': '12/17/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 5801,
#   'Impresiones': 97256,
#   'Views': 772579,
#   'Costo': 674},
#  {'Fecha': '9/24/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 3289,
#   'Impresiones': 67313,
#   'Views': 147221,
#   'Costo': 527},
#  {'Fecha': '8/26/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 2788,
#   'Impresiones': 39366,
#   'Views': 351816,
#   'Costo': 962},
#  {'Fecha': '12/10/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 9053,
#   'Impresiones': 36882,
#   'Views': 340738,
#   'Costo': 318},
#  {'Fecha': '2/27/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 7811,
#   'Impresiones': 59833,
#   'Views': 275896,
#   'Costo': 588},
#  {'Fecha': '4/8/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'South America',
#   'Clics': 4039,
#   'Impresiones': 49495,
#   'Views': 543046,
#   'Costo': 221},
#  {'Fecha': '7/14/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 2572,
#   'Impresiones': 2182,
#   'Views': 235102,
#   'Costo': 743},
#  {'Fecha': '3/25/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 749,
#   'Impresiones': 63950,
#   'Views': 493231,
#   'Costo': 175},
#  {'Fecha': '4/14/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Africa',
#   'Clics': 6656,
#   'Impresiones': 60044,
#   'Views': 229638,
#   'Costo': 460},
#  {'Fecha': '3/7/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 8422,
#   'Impresiones': 92534,
#   'Views': 840352,
#   'Costo': 493},
#  {'Fecha': '3/10/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 8324,
#   'Impresiones': 86338,
#   'Views': 742787,
#   'Costo': 464},
#  {'Fecha': '4/28/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 1383,
#   'Impresiones': 79392,
#   'Views': 813068,
#   'Costo': 831},
#  {'Fecha': '11/15/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 471,
#   'Impresiones': 63011,
#   'Views': 181757,
#   'Costo': 470},
#  {'Fecha': '4/28/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 1089,
#   'Impresiones': 49749,
#   'Views': 178288,
#   'Costo': 36},
#  {'Fecha': '3/13/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 2952,
#   'Impresiones': 24391,
#   'Views': 957241,
#   'Costo': 590},
#  {'Fecha': '3/8/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 748,
#   'Impresiones': 46109,
#   'Views': 173570,
#   'Costo': 73},
#  {'Fecha': '3/19/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 7779,
#   'Impresiones': 16545,
#   'Views': 335185,
#   'Costo': 510},
#  {'Fecha': '7/27/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 9155,
#   'Impresiones': 56188,
#   'Views': 875582,
#   'Costo': 157},
#  {'Fecha': '10/27/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 6052,
#   'Impresiones': 79347,
#   'Views': 142271,
#   'Costo': 844},
#  {'Fecha': '1/7/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 1330,
#   'Impresiones': 69770,
#   'Views': 950710,
#   'Costo': 144},
#  {'Fecha': '2/1/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 1753,
#   'Impresiones': 77734,
#   'Views': 728390,
#   'Costo': 539},
#  {'Fecha': '5/12/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 1161,
#   'Impresiones': 24941,
#   'Views': 45433,
#   'Costo': 120},
#  {'Fecha': '2/25/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 7609,
#   'Impresiones': 80711,
#   'Views': 306235,
#   'Costo': 546},
#  {'Fecha': '1/11/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 8717,
#   'Impresiones': 81550,
#   'Views': 117840,
#   'Costo': 97},
#  {'Fecha': '8/9/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 4463,
#   'Impresiones': 6896,
#   'Views': 367736,
#   'Costo': 610},
#  {'Fecha': '8/19/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 388,
#   'Impresiones': 84125,
#   'Views': 720700,
#   'Costo': 871},
#  {'Fecha': '7/16/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 2473,
#   'Impresiones': 21027,
#   'Views': 309182,
#   'Costo': 312},
#  {'Fecha': '11/4/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 2933,
#   'Impresiones': 44823,
#   'Views': 252041,
#   'Costo': 891},
#  {'Fecha': '10/13/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 3681,
#   'Impresiones': 16814,
#   'Views': 921042,
#   'Costo': 491},
#  {'Fecha': '10/29/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 5714,
#   'Impresiones': 98436,
#   'Views': 323293,
#   'Costo': 57},
#  {'Fecha': '11/2/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 1114,
#   'Impresiones': 86682,
#   'Views': 229529,
#   'Costo': 822},
#  {'Fecha': '5/14/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 5021,
#   'Impresiones': 83833,
#   'Views': 815031,
#   'Costo': 207},
#  {'Fecha': '1/12/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 1859,
#   'Impresiones': 25246,
#   'Views': 123909,
#   'Costo': 421},
#  {'Fecha': '4/26/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 2694,
#   'Impresiones': 85376,
#   'Views': 667126,
#   'Costo': 725},
#  {'Fecha': '2/21/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 4056,
#   'Impresiones': 87709,
#   'Views': 932594,
#   'Costo': 534},
#  {'Fecha': '4/7/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 3141,
#   'Impresiones': 38678,
#   'Views': 715888,
#   'Costo': 636},
#  {'Fecha': '12/9/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 7252,
#   'Impresiones': 36254,
#   'Views': 168333,
#   'Costo': 37},
#  {'Fecha': '2/27/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 5971,
#   'Impresiones': 89573,
#   'Views': 757019,
#   'Costo': 783},
#  {'Fecha': '9/22/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 8836,
#   'Impresiones': 42776,
#   'Views': 666407,
#   'Costo': 227},
#  {'Fecha': '5/12/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 4467,
#   'Impresiones': 53341,
#   'Views': 397385,
#   'Costo': 620},
#  {'Fecha': '10/7/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 6287,
#   'Impresiones': 78188,
#   'Views': 419233,
#   'Costo': 448},
#  {'Fecha': '5/13/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 1555,
#   'Impresiones': 78394,
#   'Views': 392554,
#   'Costo': 373},
#  {'Fecha': '12/7/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Africa',
#   'Clics': 795,
#   'Impresiones': 23025,
#   'Views': 749452,
#   'Costo': 778},
#  {'Fecha': '1/11/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 7116,
#   'Impresiones': 59628,
#   'Views': 810693,
#   'Costo': 77},
#  {'Fecha': '12/29/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 5067,
#   'Impresiones': 35390,
#   'Views': 983958,
#   'Costo': 732},
#  {'Fecha': '5/27/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 8371,
#   'Impresiones': 21977,
#   'Views': 552989,
#   'Costo': 119},
#  {'Fecha': '12/16/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 4226,
#   'Impresiones': 29277,
#   'Views': 88382,
#   'Costo': 765},
#  {'Fecha': '10/2/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 1520,
#   'Impresiones': 93651,
#   'Views': 916397,
#   'Costo': 591},
#  {'Fecha': '1/14/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 1822,
#   'Impresiones': 5192,
#   'Views': 590332,
#   'Costo': 399},
#  {'Fecha': '2/27/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 2698,
#   'Impresiones': 98846,
#   'Views': 466475,
#   'Costo': 923},
#  {'Fecha': '9/21/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 2123,
#   'Impresiones': 19035,
#   'Views': 904708,
#   'Costo': 990},
#  {'Fecha': '10/3/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Africa',
#   'Clics': 4365,
#   'Impresiones': 21652,
#   'Views': 917925,
#   'Costo': 675},
#  {'Fecha': '3/15/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 1430,
#   'Impresiones': 88768,
#   'Views': 279553,
#   'Costo': 367},
#  {'Fecha': '2/19/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 1834,
#   'Impresiones': 40360,
#   'Views': 200847,
#   'Costo': 753},
#  {'Fecha': '12/11/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 9178,
#   'Impresiones': 26962,
#   'Views': 384839,
#   'Costo': 352},
#  {'Fecha': '1/4/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 6351,
#   'Impresiones': 52399,
#   'Views': 175084,
#   'Costo': 853},
#  {'Fecha': '1/4/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 5479,
#   'Impresiones': 90389,
#   'Views': 601097,
#   'Costo': 837},
#  {'Fecha': '11/28/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 5795,
#   'Impresiones': 46553,
#   'Views': 335536,
#   'Costo': 475},
#  {'Fecha': '11/2/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 4636,
#   'Impresiones': 63345,
#   'Views': 13424,
#   'Costo': 837},
#  {'Fecha': '3/22/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 2060,
#   'Impresiones': 58203,
#   'Views': 604415,
#   'Costo': 871},
#  {'Fecha': '6/7/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 8395,
#   'Impresiones': 42619,
#   'Views': 260163,
#   'Costo': 962},
#  {'Fecha': '5/6/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 9295,
#   'Impresiones': 4841,
#   'Views': 523168,
#   'Costo': 28},
#  {'Fecha': '3/15/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 3061,
#   'Impresiones': 14604,
#   'Views': 166094,
#   'Costo': 677},
#  {'Fecha': '12/18/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 1372,
#   'Impresiones': 38532,
#   'Views': 791864,
#   'Costo': 21},
#  {'Fecha': '6/29/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 3352,
#   'Impresiones': 38583,
#   'Views': 626925,
#   'Costo': 713},
#  {'Fecha': '4/28/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Africa',
#   'Clics': 1395,
#   'Impresiones': 40859,
#   'Views': 886722,
#   'Costo': 417},
#  {'Fecha': '1/29/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 7435,
#   'Impresiones': 96605,
#   'Views': 664855,
#   'Costo': 671},
#  {'Fecha': '8/5/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 7641,
#   'Impresiones': 27982,
#   'Views': 591172,
#   'Costo': 264},
#  {'Fecha': '5/26/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 5781,
#   'Impresiones': 29155,
#   'Views': 732027,
#   'Costo': 989},
#  {'Fecha': '9/13/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 6976,
#   'Impresiones': 64502,
#   'Views': 408754,
#   'Costo': 958},
#  {'Fecha': '5/19/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'South America',
#   'Clics': 6595,
#   'Impresiones': 37054,
#   'Views': 331511,
#   'Costo': 701},
#  {'Fecha': '6/7/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 8570,
#   'Impresiones': 87421,
#   'Views': 257024,
#   'Costo': 729},
#  {'Fecha': '4/16/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 1633,
#   'Impresiones': 50638,
#   'Views': 705035,
#   'Costo': 848},
#  {'Fecha': '8/27/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 3422,
#   'Impresiones': 13791,
#   'Views': 120007,
#   'Costo': 400},
#  {'Fecha': '10/31/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 4607,
#   'Impresiones': 63247,
#   'Views': 100767,
#   'Costo': 946},
#  {'Fecha': '11/20/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 7247,
#   'Impresiones': 85578,
#   'Views': 587199,
#   'Costo': 903},
#  {'Fecha': '8/26/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 4257,
#   'Impresiones': 8604,
#   'Views': 761502,
#   'Costo': 541},
#  {'Fecha': '10/24/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 9540,
#   'Impresiones': 14685,
#   'Views': 596724,
#   'Costo': 721},
#  {'Fecha': '4/4/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 9227,
#   'Impresiones': 3935,
#   'Views': 920609,
#   'Costo': 440},
#  {'Fecha': '7/20/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 7730,
#   'Impresiones': 30575,
#   'Views': 632329,
#   'Costo': 134},
#  {'Fecha': '6/5/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Asia',
#   'Clics': 9344,
#   'Impresiones': 4717,
#   'Views': 50546,
#   'Costo': 335},
#  {'Fecha': '6/18/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 9011,
#   'Impresiones': 6697,
#   'Views': 341821,
#   'Costo': 618},
#  {'Fecha': '2/2/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 4374,
#   'Impresiones': 49953,
#   'Views': 449818,
#   'Costo': 644},
#  {'Fecha': '2/7/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 4365,
#   'Impresiones': 58004,
#   'Views': 800553,
#   'Costo': 356},
#  {'Fecha': '11/7/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 1926,
#   'Impresiones': 52174,
#   'Views': 973368,
#   'Costo': 370},
#  {'Fecha': '3/10/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 7446,
#   'Impresiones': 54532,
#   'Views': 970130,
#   'Costo': 964},
#  {'Fecha': '1/2/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 8000,
#   'Impresiones': 407,
#   'Views': 615102,
#   'Costo': 980},
#  {'Fecha': '1/8/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 9365,
#   'Impresiones': 65245,
#   'Views': 237023,
#   'Costo': 369},
#  {'Fecha': '11/28/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 8222,
#   'Impresiones': 796,
#   'Views': 675813,
#   'Costo': 401},
#  {'Fecha': '11/29/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 2906,
#   'Impresiones': 90049,
#   'Views': 902770,
#   'Costo': 851},
#  {'Fecha': '3/16/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 3379,
#   'Impresiones': 62409,
#   'Views': 313930,
#   'Costo': 932},
#  {'Fecha': '9/6/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 607,
#   'Impresiones': 50753,
#   'Views': 117416,
#   'Costo': 294},
#  {'Fecha': '3/21/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 2993,
#   'Impresiones': 53061,
#   'Views': 744899,
#   'Costo': 350},
#  {'Fecha': '5/20/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 1077,
#   'Impresiones': 41783,
#   'Views': 567305,
#   'Costo': 506},
#  {'Fecha': '3/16/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Europe',
#   'Clics': 9010,
#   'Impresiones': 7264,
#   'Views': 337956,
#   'Costo': 782},
#  {'Fecha': '5/5/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 9574,
#   'Impresiones': 38428,
#   'Views': 827461,
#   'Costo': 242},
#  {'Fecha': '8/9/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 6105,
#   'Impresiones': 30756,
#   'Views': 801312,
#   'Costo': 945},
#  {'Fecha': '11/16/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Europe',
#   'Clics': 870,
#   'Impresiones': 88953,
#   'Views': 652599,
#   'Costo': 698},
#  {'Fecha': '7/14/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 9152,
#   'Impresiones': 22242,
#   'Views': 192697,
#   'Costo': 25},
#  {'Fecha': '8/4/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Europe',
#   'Clics': 2201,
#   'Impresiones': 61407,
#   'Views': 303696,
#   'Costo': 40},
#  {'Fecha': '6/19/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 7071,
#   'Impresiones': 86935,
#   'Views': 631433,
#   'Costo': 639},
#  {'Fecha': '7/28/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 2971,
#   'Impresiones': 23194,
#   'Views': 841797,
#   'Costo': 343},
#  {'Fecha': '12/4/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 3115,
#   'Impresiones': 98971,
#   'Views': 468199,
#   'Costo': 50},
#  {'Fecha': '7/19/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 2530,
#   'Impresiones': 13922,
#   'Views': 845114,
#   'Costo': 908},
#  {'Fecha': '2/17/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 1613,
#   'Impresiones': 64592,
#   'Views': 37331,
#   'Costo': 711},
#  {'Fecha': '10/17/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 5420,
#   'Impresiones': 3525,
#   'Views': 393585,
#   'Costo': 391},
#  {'Fecha': '12/8/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 7188,
#   'Impresiones': 60489,
#   'Views': 500350,
#   'Costo': 2},
#  {'Fecha': '12/3/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 2867,
#   'Impresiones': 74320,
#   'Views': 523646,
#   'Costo': 616},
#  {'Fecha': '10/22/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 6858,
#   'Impresiones': 49523,
#   'Views': 668629,
#   'Costo': 600},
#  {'Fecha': '6/30/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 2455,
#   'Impresiones': 65561,
#   'Views': 650572,
#   'Costo': 79},
#  {'Fecha': '6/14/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 9286,
#   'Impresiones': 96360,
#   'Views': 943212,
#   'Costo': 119},
#  {'Fecha': '11/4/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 4005,
#   'Impresiones': 75851,
#   'Views': 672108,
#   'Costo': 767},
#  {'Fecha': '8/11/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 7886,
#   'Impresiones': 1546,
#   'Views': 85652,
#   'Costo': 899},
#  {'Fecha': '12/25/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 8652,
#   'Impresiones': 1453,
#   'Views': 850508,
#   'Costo': 170},
#  {'Fecha': '9/22/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 6591,
#   'Impresiones': 17597,
#   'Views': 216814,
#   'Costo': 987},
#  {'Fecha': '5/5/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 8241,
#   'Impresiones': 92941,
#   'Views': 445526,
#   'Costo': 465},
#  {'Fecha': '9/4/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 4157,
#   'Impresiones': 81656,
#   'Views': 713495,
#   'Costo': 181},
#  {'Fecha': '6/24/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 2214,
#   'Impresiones': 84605,
#   'Views': 74967,
#   'Costo': 834},
#  {'Fecha': '11/21/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 7199,
#   'Impresiones': 35619,
#   'Views': 740604,
#   'Costo': 800},
#  {'Fecha': '12/4/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 6585,
#   'Impresiones': 82436,
#   'Views': 682245,
#   'Costo': 889},
#  {'Fecha': '11/27/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 1182,
#   'Impresiones': 51128,
#   'Views': 562033,
#   'Costo': 176},
#  {'Fecha': '12/9/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 4991,
#   'Impresiones': 38540,
#   'Views': 694993,
#   'Costo': 2},
#  {'Fecha': '6/12/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 3763,
#   'Impresiones': 89959,
#   'Views': 749964,
#   'Costo': 96},
#  {'Fecha': '12/15/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'South America',
#   'Clics': 4260,
#   'Impresiones': 1102,
#   'Views': 388424,
#   'Costo': 970},
#  {'Fecha': '8/22/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 9613,
#   'Impresiones': 99174,
#   'Views': 58286,
#   'Costo': 356},
#  {'Fecha': '9/25/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 5607,
#   'Impresiones': 97320,
#   'Views': 165462,
#   'Costo': 496},
#  {'Fecha': '6/1/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 8661,
#   'Impresiones': 24796,
#   'Views': 910767,
#   'Costo': 740},
#  {'Fecha': '9/23/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Asia',
#   'Clics': 4130,
#   'Impresiones': 61733,
#   'Views': 253639,
#   'Costo': 651},
#  {'Fecha': '6/8/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 72,
#   'Impresiones': 82088,
#   'Views': 363808,
#   'Costo': 936},
#  {'Fecha': '7/28/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 8169,
#   'Impresiones': 19494,
#   'Views': 424263,
#   'Costo': 307},
#  {'Fecha': '1/7/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 3380,
#   'Impresiones': 50335,
#   'Views': 496551,
#   'Costo': 18},
#  {'Fecha': '8/17/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 2444,
#   'Impresiones': 80321,
#   'Views': 570306,
#   'Costo': 26},
#  {'Fecha': '6/9/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Australia',
#   'Clics': 8747,
#   'Impresiones': 79785,
#   'Views': 942111,
#   'Costo': 921},
#  {'Fecha': '9/6/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 7405,
#   'Impresiones': 23312,
#   'Views': 842930,
#   'Costo': 158},
#  {'Fecha': '3/27/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 9987,
#   'Impresiones': 49762,
#   'Views': 862455,
#   'Costo': 173},
#  {'Fecha': '12/18/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 534,
#   'Impresiones': 16693,
#   'Views': 809274,
#   'Costo': 806},
#  {'Fecha': '9/29/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 8364,
#   'Impresiones': 48017,
#   'Views': 807838,
#   'Costo': 393},
#  {'Fecha': '11/22/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 3292,
#   'Impresiones': 30181,
#   'Views': 167515,
#   'Costo': 733},
#  {'Fecha': '5/28/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 706,
#   'Impresiones': 17437,
#   'Views': 718045,
#   'Costo': 687},
#  {'Fecha': '3/14/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 6742,
#   'Impresiones': 32980,
#   'Views': 14872,
#   'Costo': 279},
#  {'Fecha': '9/7/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 3200,
#   'Impresiones': 29893,
#   'Views': 599662,
#   'Costo': 397},
#  {'Fecha': '2/15/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 2274,
#   'Impresiones': 99257,
#   'Views': 280134,
#   'Costo': 727},
#  {'Fecha': '7/11/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 3148,
#   'Impresiones': 50715,
#   'Views': 688164,
#   'Costo': 972},
#  {'Fecha': '10/3/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 758,
#   'Impresiones': 78534,
#   'Views': 120050,
#   'Costo': 163},
#  {'Fecha': '11/4/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 4577,
#   'Impresiones': 67641,
#   'Views': 406087,
#   'Costo': 954},
#  {'Fecha': '3/9/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 3612,
#   'Impresiones': 86987,
#   'Views': 603399,
#   'Costo': 967},
#  {'Fecha': '10/26/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 5825,
#   'Impresiones': 98675,
#   'Views': 3928,
#   'Costo': 492},
#  {'Fecha': '7/25/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 1294,
#   'Impresiones': 10837,
#   'Views': 761920,
#   'Costo': 326},
#  {'Fecha': '10/30/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 9940,
#   'Impresiones': 82637,
#   'Views': 720702,
#   'Costo': 763},
#  {'Fecha': '1/25/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Africa',
#   'Clics': 2244,
#   'Impresiones': 63645,
#   'Views': 898757,
#   'Costo': 893},
#  {'Fecha': '6/19/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 9142,
#   'Impresiones': 47496,
#   'Views': 212371,
#   'Costo': 132},
#  {'Fecha': '12/27/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 8618,
#   'Impresiones': 62515,
#   'Views': 221172,
#   'Costo': 665},
#  {'Fecha': '4/2/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 7087,
#   'Impresiones': 22822,
#   'Views': 763263,
#   'Costo': 903},
#  {'Fecha': '4/8/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 9841,
#   'Impresiones': 81018,
#   'Views': 883579,
#   'Costo': 150},
#  {'Fecha': '1/18/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'South America',
#   'Clics': 5978,
#   'Impresiones': 10730,
#   'Views': 62173,
#   'Costo': 495},
#  {'Fecha': '8/26/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 9588,
#   'Impresiones': 57482,
#   'Views': 404601,
#   'Costo': 266},
#  {'Fecha': '11/10/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 8422,
#   'Impresiones': 7528,
#   'Views': 614387,
#   'Costo': 508},
#  {'Fecha': '4/24/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 1004,
#   'Impresiones': 80068,
#   'Views': 535963,
#   'Costo': 943},
#  {'Fecha': '7/30/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 8153,
#   'Impresiones': 37427,
#   'Views': 999049,
#   'Costo': 312},
#  {'Fecha': '8/23/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Europe',
#   'Clics': 2020,
#   'Impresiones': 87442,
#   'Views': 958341,
#   'Costo': 212},
#  {'Fecha': '5/20/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 1334,
#   'Impresiones': 20914,
#   'Views': 668919,
#   'Costo': 18},
#  {'Fecha': '2/2/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 4559,
#   'Impresiones': 51873,
#   'Views': 296950,
#   'Costo': 915},
#  {'Fecha': '4/20/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 3942,
#   'Impresiones': 62090,
#   'Views': 241629,
#   'Costo': 429},
#  {'Fecha': '4/16/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 1582,
#   'Impresiones': 59980,
#   'Views': 901844,
#   'Costo': 981},
#  {'Fecha': '12/28/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 1014,
#   'Impresiones': 39867,
#   'Views': 499298,
#   'Costo': 448},
#  {'Fecha': '1/12/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 9433,
#   'Impresiones': 92155,
#   'Views': 980695,
#   'Costo': 337},
#  {'Fecha': '11/3/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 1565,
#   'Impresiones': 22554,
#   'Views': 570807,
#   'Costo': 167},
#  {'Fecha': '4/18/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 5095,
#   'Impresiones': 18414,
#   'Views': 273175,
#   'Costo': 371},
#  {'Fecha': '4/1/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 7143,
#   'Impresiones': 77838,
#   'Views': 387771,
#   'Costo': 590},
#  {'Fecha': '10/9/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 9963,
#   'Impresiones': 83494,
#   'Views': 135824,
#   'Costo': 451},
#  {'Fecha': '8/30/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 9485,
#   'Impresiones': 46198,
#   'Views': 707016,
#   'Costo': 991},
#  {'Fecha': '12/16/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 6154,
#   'Impresiones': 53182,
#   'Views': 466764,
#   'Costo': 413},
#  {'Fecha': '5/10/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 1513,
#   'Impresiones': 75728,
#   'Views': 89427,
#   'Costo': 632},
#  {'Fecha': '7/28/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 8515,
#   'Impresiones': 4671,
#   'Views': 984703,
#   'Costo': 585},
#  {'Fecha': '10/19/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 1818,
#   'Impresiones': 62945,
#   'Views': 956135,
#   'Costo': 282},
#  {'Fecha': '11/26/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 294,
#   'Impresiones': 59221,
#   'Views': 370848,
#   'Costo': 222},
#  {'Fecha': '7/16/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 5835,
#   'Impresiones': 19838,
#   'Views': 141561,
#   'Costo': 46},
#  {'Fecha': '1/12/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Africa',
#   'Clics': 8404,
#   'Impresiones': 55360,
#   'Views': 535609,
#   'Costo': 610},
#  {'Fecha': '8/19/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 5811,
#   'Impresiones': 21947,
#   'Views': 699284,
#   'Costo': 537},
#  {'Fecha': '1/23/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 6886,
#   'Impresiones': 64712,
#   'Views': 438440,
#   'Costo': 135},
#  {'Fecha': '2/1/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 9066,
#   'Impresiones': 44971,
#   'Views': 412031,
#   'Costo': 574},
#  {'Fecha': '7/20/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 7734,
#   'Impresiones': 95259,
#   'Views': 381679,
#   'Costo': 865},
#  {'Fecha': '3/11/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 6209,
#   'Impresiones': 98709,
#   'Views': 474003,
#   'Costo': 450},
#  {'Fecha': '1/27/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 7150,
#   'Impresiones': 38390,
#   'Views': 172543,
#   'Costo': 265},
#  {'Fecha': '1/27/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Africa',
#   'Clics': 5763,
#   'Impresiones': 37261,
#   'Views': 330773,
#   'Costo': 478},
#  {'Fecha': '12/23/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Africa',
#   'Clics': 3188,
#   'Impresiones': 15383,
#   'Views': 993149,
#   'Costo': 828},
#  {'Fecha': '12/16/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Europe',
#   'Clics': 573,
#   'Impresiones': 34080,
#   'Views': 736881,
#   'Costo': 624},
#  {'Fecha': '12/18/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Europe',
#   'Clics': 5700,
#   'Impresiones': 90744,
#   'Views': 434858,
#   'Costo': 746},
#  {'Fecha': '12/2/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 399,
#   'Impresiones': 88356,
#   'Views': 997747,
#   'Costo': 639},
#  {'Fecha': '4/6/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 2438,
#   'Impresiones': 6118,
#   'Views': 19994,
#   'Costo': 971},
#  {'Fecha': '1/8/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 5358,
#   'Impresiones': 23888,
#   'Views': 885949,
#   'Costo': 741},
#  {'Fecha': '10/7/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 427,
#   'Impresiones': 55315,
#   'Views': 677722,
#   'Costo': 536},
#  {'Fecha': '5/1/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 3179,
#   'Impresiones': 13670,
#   'Views': 534454,
#   'Costo': 156},
#  {'Fecha': '6/26/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 6189,
#   'Impresiones': 60304,
#   'Views': 270821,
#   'Costo': 387},
#  {'Fecha': '8/8/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 924,
#   'Impresiones': 99480,
#   'Views': 969767,
#   'Costo': 149},
#  {'Fecha': '6/22/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'South America',
#   'Clics': 4128,
#   'Impresiones': 65949,
#   'Views': 572822,
#   'Costo': 669},
# ...
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Europe',
#   'Clics': 4747,
#   'Impresiones': 22497,
#   'Views': 71941,
#   'Costo': 758},
#  {'Fecha': '1/7/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 6848,
#   'Impresiones': 94949,
#   'Views': 243899,
#   'Costo': 926},
#  {'Fecha': '10/19/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 4695,
#   'Impresiones': 12899,
#   'Views': 83145,
#   'Costo': 529},
#  {'Fecha': '10/31/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 7228,
#   'Impresiones': 28911,
#   'Views': 458956,
#   'Costo': 575},
#  {'Fecha': '2/17/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 3755,
#   'Impresiones': 13299,
#   'Views': 254270,
#   'Costo': 99},
#  {'Fecha': '1/28/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 32,
#   'Impresiones': 79465,
#   'Views': 457957,
#   'Costo': 626},
#  {'Fecha': '8/26/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Africa',
#   'Clics': 6193,
#   'Impresiones': 38247,
#   'Views': 52138,
#   'Costo': 471},
#  {'Fecha': '4/19/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 6133,
#   'Impresiones': 60347,
#   'Views': 141503,
#   'Costo': 691},
#  {'Fecha': '1/29/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 496,
#   'Impresiones': 84433,
#   'Views': 316605,
#   'Costo': 797},
#  {'Fecha': '8/23/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 1788,
#   'Impresiones': 88711,
#   'Views': 402327,
#   'Costo': 69},
#  {'Fecha': '5/30/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 1484,
#   'Impresiones': 94876,
#   'Views': 379295,
#   'Costo': 207},
#  {'Fecha': '10/15/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 4455,
#   'Impresiones': 31809,
#   'Views': 51958,
#   'Costo': 295},
#  {'Fecha': '10/17/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 493,
#   'Impresiones': 13013,
#   'Views': 531320,
#   'Costo': 529},
#  {'Fecha': '9/19/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 8048,
#   'Impresiones': 85396,
#   'Views': 971170,
#   'Costo': 520},
#  {'Fecha': '7/5/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 5951,
#   'Impresiones': 29583,
#   'Views': 327764,
#   'Costo': 757},
#  {'Fecha': '9/24/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 221,
#   'Impresiones': 40253,
#   'Views': 468662,
#   'Costo': 981},
#  {'Fecha': '2/24/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 4578,
#   'Impresiones': 68385,
#   'Views': 649508,
#   'Costo': 217},
#  {'Fecha': '7/18/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 2255,
#   'Impresiones': 98336,
#   'Views': 360783,
#   'Costo': 986},
#  {'Fecha': '5/3/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 5814,
#   'Impresiones': 89821,
#   'Views': 996776,
#   'Costo': 431},
#  {'Fecha': '3/28/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Africa',
#   'Clics': 9446,
#   'Impresiones': 72037,
#   'Views': 697505,
#   'Costo': 949},
#  {'Fecha': '5/1/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 1746,
#   'Impresiones': 74549,
#   'Views': 140383,
#   'Costo': 428},
#  {'Fecha': '3/25/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 301,
#   'Impresiones': 99700,
#   'Views': 458075,
#   'Costo': 364},
#  {'Fecha': '5/27/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'South America',
#   'Clics': 8483,
#   'Impresiones': 86538,
#   'Views': 228126,
#   'Costo': 354},
#  {'Fecha': '4/17/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 9888,
#   'Impresiones': 45889,
#   'Views': 710428,
#   'Costo': 91},
#  {'Fecha': '12/5/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 8909,
#   'Impresiones': 50904,
#   'Views': 717601,
#   'Costo': 456},
#  {'Fecha': '1/26/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'South America',
#   'Clics': 8753,
#   'Impresiones': 33442,
#   'Views': 115799,
#   'Costo': 478},
#  {'Fecha': '9/26/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Asia',
#   'Clics': 6974,
#   'Impresiones': 25429,
#   'Views': 565813,
#   'Costo': 848},
#  {'Fecha': '8/18/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 1808,
#   'Impresiones': 96485,
#   'Views': 838675,
#   'Costo': 273},
#  {'Fecha': '11/1/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 2165,
#   'Impresiones': 73560,
#   'Views': 775537,
#   'Costo': 384},
#  {'Fecha': '12/4/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 7660,
#   'Impresiones': 34646,
#   'Views': 682227,
#   'Costo': 528},
#  {'Fecha': '9/3/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'South America',
#   'Clics': 6828,
#   'Impresiones': 37553,
#   'Views': 796961,
#   'Costo': 312},
#  {'Fecha': '12/11/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 7156,
#   'Impresiones': 27841,
#   'Views': 482208,
#   'Costo': 871},
#  {'Fecha': '6/15/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 9315,
#   'Impresiones': 35480,
#   'Views': 108752,
#   'Costo': 855},
#  {'Fecha': '1/31/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Asia',
#   'Clics': 7943,
#   'Impresiones': 38370,
#   'Views': 766525,
#   'Costo': 708},
#  {'Fecha': '2/6/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'South America',
#   'Clics': 5142,
#   'Impresiones': 36271,
#   'Views': 925632,
#   'Costo': 83},
#  {'Fecha': '2/8/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Australia',
#   'Clics': 1222,
#   'Impresiones': 85760,
#   'Views': 85913,
#   'Costo': 584},
#  {'Fecha': '11/30/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 361,
#   'Impresiones': 87149,
#   'Views': 606280,
#   'Costo': 952},
#  {'Fecha': '3/17/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'North America',
#   'Clics': 7010,
#   'Impresiones': 70348,
#   'Views': 713997,
#   'Costo': 875},
#  {'Fecha': '3/26/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 9158,
#   'Impresiones': 15434,
#   'Views': 319078,
#   'Costo': 818},
#  {'Fecha': '12/14/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 7052,
#   'Impresiones': 18445,
#   'Views': 399164,
#   'Costo': 90},
#  {'Fecha': '12/18/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 5668,
#   'Impresiones': 51250,
#   'Views': 472274,
#   'Costo': 667},
#  {'Fecha': '8/30/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 8228,
#   'Impresiones': 70381,
#   'Views': 891912,
#   'Costo': 824},
#  {'Fecha': '9/24/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 2403,
#   'Impresiones': 10649,
#   'Views': 744747,
#   'Costo': 116},
#  {'Fecha': '4/4/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 6824,
#   'Impresiones': 28698,
#   'Views': 719547,
#   'Costo': 953},
#  {'Fecha': '8/30/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 4048,
#   'Impresiones': 87359,
#   'Views': 487692,
#   'Costo': 649},
#  {'Fecha': '11/27/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 2475,
#   'Impresiones': 29603,
#   'Views': 561323,
#   'Costo': 165},
#  {'Fecha': '11/1/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 7098,
#   'Impresiones': 29773,
#   'Views': 31339,
#   'Costo': 125},
#  {'Fecha': '2/22/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 5733,
#   'Impresiones': 27672,
#   'Views': 955385,
#   'Costo': 217},
#  {'Fecha': '5/23/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Australia',
#   'Clics': 4416,
#   'Impresiones': 2056,
#   'Views': 821434,
#   'Costo': 963},
#  {'Fecha': '5/30/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 1065,
#   'Impresiones': 19534,
#   'Views': 539048,
#   'Costo': 49},
#  {'Fecha': '6/15/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 1854,
#   'Impresiones': 85900,
#   'Views': 771106,
#   'Costo': 965},
#  {'Fecha': '7/25/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 2517,
#   'Impresiones': 68642,
#   'Views': 81563,
#   'Costo': 460},
#  {'Fecha': '6/7/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Asia',
#   'Clics': 928,
#   'Impresiones': 21647,
#   'Views': 346651,
#   'Costo': 195},
#  {'Fecha': '8/19/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 4597,
#   'Impresiones': 9157,
#   'Views': 496687,
#   'Costo': 73},
#  {'Fecha': '10/24/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 2389,
#   'Impresiones': 70473,
#   'Views': 61297,
#   'Costo': 471},
#  {'Fecha': '12/14/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Australia',
#   'Clics': 3701,
#   'Impresiones': 17549,
#   'Views': 598673,
#   'Costo': 788},
#  {'Fecha': '6/29/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 1865,
#   'Impresiones': 3476,
#   'Views': 341253,
#   'Costo': 662},
#  {'Fecha': '5/29/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 3795,
#   'Impresiones': 62243,
#   'Views': 925938,
#   'Costo': 900},
#  {'Fecha': '1/29/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 4683,
#   'Impresiones': 28256,
#   'Views': 519855,
#   'Costo': 235},
#  {'Fecha': '7/24/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 8431,
#   'Impresiones': 65081,
#   'Views': 396748,
#   'Costo': 80},
#  {'Fecha': '1/22/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Australia',
#   'Clics': 5329,
#   'Impresiones': 94519,
#   'Views': 647208,
#   'Costo': 900},
#  {'Fecha': '4/25/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'North America',
#   'Clics': 9933,
#   'Impresiones': 6860,
#   'Views': 323665,
#   'Costo': 629},
#  {'Fecha': '3/2/2020',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Australia',
#   'Clics': 5501,
#   'Impresiones': 14215,
#   'Views': 295751,
#   'Costo': 689},
#  {'Fecha': '10/23/2020',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 8479,
#   'Impresiones': 9606,
#   'Views': 435526,
#   'Costo': 996},
#  {'Fecha': '2/22/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 8793,
#   'Impresiones': 36998,
#   'Views': 495173,
#   'Costo': 203},
#  {'Fecha': '7/7/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'South America',
#   'Clics': 6981,
#   'Impresiones': 25819,
#   'Views': 941596,
#   'Costo': 826},
#  {'Fecha': '12/22/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'North America',
#   'Clics': 481,
#   'Impresiones': 59705,
#   'Views': 816019,
#   'Costo': 380},
#  {'Fecha': '4/3/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 1182,
#   'Impresiones': 49938,
#   'Views': 930101,
#   'Costo': 583},
#  {'Fecha': '9/8/2020',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Europe',
#   'Clics': 2590,
#   'Impresiones': 9343,
#   'Views': 970576,
#   'Costo': 679},
#  {'Fecha': '11/13/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Europe',
#   'Clics': 2471,
#   'Impresiones': 48718,
#   'Views': 458659,
#   'Costo': 345},
#  {'Fecha': '2/16/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Africa',
#   'Clics': 1374,
#   'Impresiones': 36300,
#   'Views': 77239,
#   'Costo': 475},
#  {'Fecha': '6/5/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'South America',
#   'Clics': 6837,
#   'Impresiones': 80525,
#   'Views': 978235,
#   'Costo': 876},
#  {'Fecha': '6/17/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 619,
#   'Impresiones': 99280,
#   'Views': 509375,
#   'Costo': 689},
#  {'Fecha': '5/30/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 1285,
#   'Impresiones': 94747,
#   'Views': 231400,
#   'Costo': 136},
#  {'Fecha': '6/15/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'South America',
#   'Clics': 5649,
#   'Impresiones': 35375,
#   'Views': 218394,
#   'Costo': 104},
#  {'Fecha': '12/23/2020',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 1606,
#   'Impresiones': 55072,
#   'Views': 166602,
#   'Costo': 674},
#  {'Fecha': '8/21/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 1963,
#   'Impresiones': 30648,
#   'Views': 450756,
#   'Costo': 377},
#  {'Fecha': '11/12/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 7933,
#   'Impresiones': 30876,
#   'Views': 218842,
#   'Costo': 649},
#  {'Fecha': '12/14/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'South America',
#   'Clics': 5198,
#   'Impresiones': 23039,
#   'Views': 251141,
#   'Costo': 991},
#  {'Fecha': '4/30/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 7054,
#   'Impresiones': 53231,
#   'Views': 526314,
#   'Costo': 834},
#  {'Fecha': '5/10/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'North America',
#   'Clics': 3104,
#   'Impresiones': 80940,
#   'Views': 342120,
#   'Costo': 235},
#  {'Fecha': '2/21/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Australia',
#   'Clics': 5570,
#   'Impresiones': 82841,
#   'Views': 199515,
#   'Costo': 232},
#  {'Fecha': '2/4/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'North America',
#   'Clics': 2623,
#   'Impresiones': 67042,
#   'Views': 513836,
#   'Costo': 603},
#  {'Fecha': '5/13/2021',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Asia',
#   'Clics': 1751,
#   'Impresiones': 65296,
#   'Views': 777241,
#   'Costo': 291},
#  {'Fecha': '10/16/2021',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 4187,
#   'Impresiones': 94213,
#   'Views': 875040,
#   'Costo': 741},
#  {'Fecha': '6/5/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 3515,
#   'Impresiones': 62341,
#   'Views': 546192,
#   'Costo': 402},
#  {'Fecha': '4/13/2022',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Europe',
#   'Clics': 760,
#   'Impresiones': 69974,
#   'Views': 121407,
#   'Costo': 340},
#  {'Fecha': '12/4/2020',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'North America',
#   'Clics': 609,
#   'Impresiones': 62014,
#   'Views': 884217,
#   'Costo': 38},
#  {'Fecha': '8/8/2021',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Africa',
#   'Clics': 97,
#   'Impresiones': 73224,
#   'Views': 33249,
#   'Costo': 788},
#  {'Fecha': '3/10/2022',
#   'Nombre de la campaña': 'Mrs',
#   'Region': 'Asia',
#   'Clics': 2503,
#   'Impresiones': 73567,
#   'Views': 482920,
#   'Costo': 644},
#  {'Fecha': '5/29/2022',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Africa',
#   'Clics': 1315,
#   'Impresiones': 12470,
#   'Views': 727045,
#   'Costo': 51},
#  {'Fecha': '6/18/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 4690,
#   'Impresiones': 9692,
#   'Views': 207205,
#   'Costo': 619},
#  {'Fecha': '7/13/2021',
#   'Nombre de la campaña': 'Honorable',
#   'Region': 'Australia',
#   'Clics': 161,
#   'Impresiones': 54648,
#   'Views': 818471,
#   'Costo': 747},
#  {'Fecha': '11/13/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 5827,
#   'Impresiones': 96540,
#   'Views': 585265,
#   'Costo': 197},
#  {'Fecha': '4/27/2021',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Australia',
#   'Clics': 9667,
#   'Impresiones': 88472,
#   'Views': 411546,
#   'Costo': 955},
#  {'Fecha': '6/6/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 2509,
#   'Impresiones': 91183,
#   'Views': 964141,
#   'Costo': 642},
#  {'Fecha': '9/23/2022',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Europe',
#   'Clics': 1992,
#   'Impresiones': 79918,
#   'Views': 374586,
#   'Costo': 974},
#  {'Fecha': '9/28/2020',
#   'Nombre de la campaña': 'Dr',
#   'Region': 'Africa',
#   'Clics': 153,
#   'Impresiones': 36635,
#   'Views': 414400,
#   'Costo': 633},
#  {'Fecha': '1/24/2022',
#   'Nombre de la campaña': 'Ms',
#   'Region': 'Asia',
#   'Clics': 7392,
#   'Impresiones': 85338,
#   'Views': 775556,
#   'Costo': 824},
#  {'Fecha': '1/24/2021',
#   'Nombre de la campaña': 'Rev',
#   'Region': 'Asia',
#   'Clics': 8764,
#   'Impresiones': 28374,
#   'Views': 462122,
#   'Costo': 752},
#  {'Fecha': '8/22/2022',
#   'Nombre de la campaña': 'Mr',
#   'Region': 'Asia',
#   'Clics': 5808,
#   'Impresiones': 15885,
#   'Views': 478970,
#   'Costo': 93}]

# %% [markdown]
# leamos este json con pandas.

# %%
pd.read_json(StringIO(response.text))
# Out:
#          Fecha Nombre de la campaña         Region  Clics  Impresiones  \
# 0    6/21/2021                  Mrs         Africa   5859        52117
# 1    8/26/2021                  Mrs      Australia   1984        15857
# 2    8/28/2021            Honorable         Europe   8467        65543
# 3    9/22/2021                  Rev  South America   5355        23645
# 4    3/19/2020                  Rev         Europe   5550        69030
# ..         ...                  ...            ...    ...          ...
# 995  9/23/2022                  Rev         Europe   1992        79918
# 996  9/28/2020                   Dr         Africa    153        36635
# 997  1/24/2022                   Ms           Asia   7392        85338
# 998  1/24/2021                  Rev           Asia   8764        28374
# 999  8/22/2022                   Mr           Asia   5808        15885
#
#       Views  Costo
# 0    151573    620
# 1    963171    626
# 2    230241    616
# 3    229958    464
# 4    527332    855
# ..      ...    ...
# 995  374586    974
# 996  414400    633
# 997  775556    824
# 998  462122    752
# 999  478970     93
#
# [1000 rows x 7 columns]
